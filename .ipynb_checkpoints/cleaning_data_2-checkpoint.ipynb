# %%
import pandas as pd

# %%
df = pd.read_csv('data/USCS_StateCountyMap.csv')
df.head()
# Out:
#          Area               County           CancerType         Year  \
# 0  'Illinois'        'Kane County'  'Lung and Bronchus'  '2012-2016'
# 1  'Illinois'      'DuPage County'  'Lung and Bronchus'  '2012-2016'
# 2  'Illinois'   'Champaign County'  'Lung and Bronchus'  '2012-2016'
# 3  'Illinois'    'Woodford County'  'Lung and Bronchus'  '2012-2016'
# 4  'Illinois'  'Stephenson County'  'Lung and Bronchus'  '2012-2016'
#
#                  Sex AgeAdjustedRate     lci     uci CaseCount Population
# 0  'Male and Female'          '51.2'  '48.4'  '54.1'    '1298'  '2633345'
# 1  'Male and Female'          '51.8'  '49.7'  '53.8'    '2643'  '4657275'
# 2  'Male and Female'          '52.8'  '48.2'  '57.8'     '499'  '1034430'
# 3  'Male and Female'          '54.8'  '45.7'  '65.2'     '135'   '194822'
# 4  'Male and Female'          '52.4'    '45'  '60.9'     '186'   '231025'

# %%
df.loc[(df.County=='Franklin County') | (df.County == 'Peoria County') | (df.County == 'Cook County') | (df.County == 'DuPage County')]
# Out:
# Empty DataFrame
# Columns: [Area, County, CancerType, Year, Sex, AgeAdjustedRate, lci, uci, CaseCount, Population]
# Index: []

# %%
df['County'] = df['County'].astype(str)

# %%
df.dtypes
# Out:
# Area               object
# County             object
# CancerType         object
# Year               object
# Sex                object
# AgeAdjustedRate    object
# lci                object
# uci                object
# CaseCount          object
# Population         object
# dtype: object

# %%
type(df['County'][0])
# Out:
# str

# %%
df.loc[(df.County=='Franklin County') | (df.County == 'Peoria County') | (df.County == 'Cook County') | (df.County == 'DuPage County')]
# Out:
# Empty DataFrame
# Columns: [Area, County, CancerType, Year, Sex, AgeAdjustedRate, lci, uci, CaseCount, Population]
# Index: []

# %%
df[df.County=='\'Franklin County\'']
# Out:
#           Area             County           CancerType         Year  \
# 46  'Illinois'  'Franklin County'  'Lung and Bronchus'  '2012-2016'
#
#                   Sex AgeAdjustedRate     lci    uci CaseCount Population
# 46  'Male and Female'         '108.8'  '96.9'  '122'     '312'   '197320'

# %%
df.head()
# Out:
#          Area               County           CancerType         Year  \
# 0  'Illinois'        'Kane County'  'Lung and Bronchus'  '2012-2016'
# 1  'Illinois'      'DuPage County'  'Lung and Bronchus'  '2012-2016'
# 2  'Illinois'   'Champaign County'  'Lung and Bronchus'  '2012-2016'
# 3  'Illinois'    'Woodford County'  'Lung and Bronchus'  '2012-2016'
# 4  'Illinois'  'Stephenson County'  'Lung and Bronchus'  '2012-2016'
#
#                  Sex AgeAdjustedRate     lci     uci CaseCount Population
# 0  'Male and Female'          '51.2'  '48.4'  '54.1'    '1298'  '2633345'
# 1  'Male and Female'          '51.8'  '49.7'  '53.8'    '2643'  '4657275'
# 2  'Male and Female'          '52.8'  '48.2'  '57.8'     '499'  '1034430'
# 3  'Male and Female'          '54.8'  '45.7'  '65.2'     '135'   '194822'
# 4  'Male and Female'          '52.4'    '45'  '60.9'     '186'   '231025'

# %%
df = df.applymap(lambda x: x[1:])
df
# Out:
#           Area              County          CancerType        Year  \
# 0    Illinois'        Kane County'  Lung and Bronchus'  2012-2016'
# 1    Illinois'      DuPage County'  Lung and Bronchus'  2012-2016'
# 2    Illinois'   Champaign County'  Lung and Bronchus'  2012-2016'
# 3    Illinois'    Woodford County'  Lung and Bronchus'  2012-2016'
# 4    Illinois'  Stephenson County'  Lung and Bronchus'  2012-2016'
# 5    Illinois'      Wabash County'  Lung and Bronchus'  2012-2016'
# 6    Illinois'     Calhoun County'  Lung and Bronchus'  2012-2016'
# 7    Illinois'     Carroll County'  Lung and Bronchus'  2012-2016'
# 8    Illinois'       Boone County'  Lung and Bronchus'  2012-2016'
# 9    Illinois'   Effingham County'  Lung and Bronchus'  2012-2016'
# 10   Illinois'  Jo Daviess County'  Lung and Bronchus'  2012-2016'
# 11   Illinois'         Lee County'  Lung and Bronchus'  2012-2016'
# 12   Illinois'      DeKalb County'  Lung and Bronchus'  2012-2016'
# ...

# %%
df = df.applymap(lambda x: x[:-1])
df
# Out:
#          Area             County         CancerType       Year  \
# 0    Illinois        Kane County  Lung and Bronchus  2012-2016
# 1    Illinois      DuPage County  Lung and Bronchus  2012-2016
# 2    Illinois   Champaign County  Lung and Bronchus  2012-2016
# 3    Illinois    Woodford County  Lung and Bronchus  2012-2016
# 4    Illinois  Stephenson County  Lung and Bronchus  2012-2016
# 5    Illinois      Wabash County  Lung and Bronchus  2012-2016
# 6    Illinois     Calhoun County  Lung and Bronchus  2012-2016
# 7    Illinois     Carroll County  Lung and Bronchus  2012-2016
# 8    Illinois       Boone County  Lung and Bronchus  2012-2016
# 9    Illinois   Effingham County  Lung and Bronchus  2012-2016
# 10   Illinois  Jo Daviess County  Lung and Bronchus  2012-2016
# 11   Illinois         Lee County  Lung and Bronchus  2012-2016
# 12   Illinois      DeKalb County  Lung and Bronchus  2012-2016
# 13   Illinois     McHenry County  Lung and Bronchus  2012-2016
# ...

# %%
df = df.loc[(df.County=='Franklin County') | (df.County == 'Peoria County') | (df.County == 'Cook County') | (df.County == 'DuPage County')]
df
# Out:
#         Area           County         CancerType       Year              Sex  \
# 1   Illinois    DuPage County  Lung and Bronchus  2012-2016  Male and Female
# 28  Illinois      Cook County  Lung and Bronchus  2012-2016  Male and Female
# 46  Illinois  Franklin County  Lung and Bronchus  2012-2016  Male and Female
# 82  Illinois    Peoria County  Lung and Bronchus  2012-2016  Male and Female
#
#    AgeAdjustedRate   lci   uci CaseCount Population
# 1             51.8  49.7  53.8      2643    4657275
# 28            59.3  58.3  60.2     16642   26218615
# 46           108.8  96.9   122       312     197320
# 82            83.1  77.7  88.7       934     934904

# %%
df.drop(columns=['Area', 'CancerType', 'Sex', 'lci', 'uci'], inplace=True)
df
# Out:
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#              County       Year AgeAdjustedRate CaseCount Population
# 1     DuPage County  2012-2016            51.8      2643    4657275
# 28      Cook County  2012-2016            59.3     16642   26218615
# 46  Franklin County  2012-2016           108.8       312     197320
# 82    Peoria County  2012-2016            83.1       934     934904

# %%
cleaned_df = df.to_csv('cancer_incidence_by_county.csv')

# %% [markdown]
# ## Data Fetching
# This interactive notebook handles the fetching and cleaning of data from the EPA's Air Quality System. To do so, we should start by importing some of our required libraries, including our custom created `pyaqs` module that provides wrapper methods to convert information stored in the AQS REST API to easily accessible and modifiable Pandas dataframes.

# %%
from pyaqs import AQSFetcher
import pandas as pd
from time import sleep
import numpy as np

# %% [markdown]
# Now, we will instantiate a new AQSFetcher object and use it to get the required data from the EPA website. From our previous investigation of the four states of Illinois, New York, California, and Georgia, we have concluded that we need more data in order to draw any substantial conclusions, negative or positive. Therefore, in this notebook, we will be fetching data for all 50 states, for the criteria parameters as defined by the EPA.
#
# To note, in this context, a *parameter* is a compound that in the air that can be measured. The EPA has many such parameters, sorted into different classes whose descriptions are easily accessible through the API.
#
# Let's start by instantiating a fetcher object, and we'll use it to get the list of state codes so that we can easily query the API in an automated way.

# %%
aqs_fetcher = AQSFetcher('bbjornstad.flatiron@gmail.com', 'ochrefox21')

# %%
state_codes = aqs_fetcher.get_state_codes()
state_codes.head()
# Out:
#   code  state_name
# 0   01     Alabama
# 1   02      Alaska
# 2   04     Arizona
# 3   05    Arkansas
# 4   06  California

# %% [markdown]
# Next, let's take a look at the possible parameter classes and identify a set that seems reasonable for analysis.

# %%
aqs_fetcher.get_parameter_classes()
# Out:
#                  class_name                                  class_description
# 0               AIRNOW MAPS  The parameters represented on AirNow maps (881...
# 1                       ALL                    Select all Parameters Available
# 2            AQI POLLUTANTS                Pollutants that have an AQI Defined
# 3                 CORE_HAPS                         Urban Air Toxic Pollutants
# 4                  CRITERIA                                Criteria Pollutants
# 5                  CSN DART  List of CSN speciation parameters to populate ...
# 6                  FORECAST     Parameters routinely extracted by AirNow (STI)
# 7                      HAPS                           Hazardous Air Pollutants
# 8            IMPROVE CARBON                          IMPROVE Carbon Parameters
# 9        IMPROVE_SPECIATION  PM2.5 Speciated Parameters Measured at IMPROVE...
# 10                      MET                            Meteorologic Parameters
# 11          NATTS CORE HAPS  The core list of toxics of interest to the NAT...
# 12           NATTS REQUIRED  Required compounds to be collected in the Nati...
# 13                     PAMS         Photochemical Assessment Monitoring System
# 14                 PAMS_VOC  Volatile Organic Compound subset of the PAMS P...
# 15                PM COARSE                  PM between 2.5 and 10 micrometers
# 16          PM10 SPECIATION                          PM10 Speciated Parameters
# 17        PM2.5 CONT NONREF             PM2.5 Continuous, Nonreference Methods
# 18            PM2.5 MASS/QA                       PM2.5 Mass and QA Parameters
# 19        SCHOOL AIR TOXICS                          School Air Toxics Program
# 20               SPECIATION                         PM2.5 Speciated Parameters
# 21        SPECIATION CARBON                 PM2.5 Speciation Carbon Pollutants
# 22  SPECIATION CATION/ANION           PM2.5 Speciation Cation/Anion Pollutants
# 23        SPECIATION METALS                 PM2.5 Speciation Metals Pollutants
# 24           UATMP CARBONYL      Urban Air Toxics Monitoring Program Carbonyls
# 25                UATMP VOC           Urban Air Toxics Monitoring Program VOCs

# %% [markdown]
# We are most interested in those parameters held in the CRITERIA class, as indicated by the description. In particular, this class defines pollutants that the EPA has determined to be suitable criteria for overall air quality. Let's store these parameters and their associated codes for easy grouping later on.

# %%
parameter_codes = aqs_fetcher.get_parameter_list_by_class('CRITERIA')
parameter_codes
# Out:
#     code     parameter_description
# 0  14129             Lead (TSP) LC
# 1  42101           Carbon monoxide
# 2  42401            Sulfur dioxide
# 3  42602    Nitrogen dioxide (NO2)
# 4  44201                     Ozone
# 5  81102     PM10 Total 0-10um STP
# 6  85129      Lead PM10 LC FRM/FEM
# 7  88101  PM2.5 - Local Conditions

# %% [markdown]
# Fantastic, these will allow us the possibility to easily partition and query the data that we need to continue with the analysis. Let's now use these parameters and our AQSFetcher object to get annual summary data by state between the periods of 2012 to 2016.
#
# *WARNING: this cell will take quite some time to run, due to the nature of fetching data from a web API. This raw dataframe is saved to the [`data`](./data/) folder, to save quite a bit of time and further headache*

# %%
all_state_aq_data = pd.DataFrame()

for state_code in state_codes.code:
    all_state_aq_data = pd.concat(
        [all_state_aq_data, 
         aqs_fetcher.annual_data_by_state(state_code, parameter_codes.code, 20120101, 20161231)])
    # sleep to not break the API
    sleep(np.random.rand()*0.25)

all_state_aq_data.head()
# Out:
# No matching data could be found!
# Bad URL!
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         01         083        0005          14129    1  34.645848
# 1         01         073        2059          42101    1  33.521427
# 2         01         073        2059          42101    1  33.521427
# 3         01         073        2059          42101    1  33.521427
# 4         01         073        2059          42101    1  33.521427
#
#    longitude  datum        parameter        sample_duration  ...  \
# 0 -86.947311  WGS84    Lead (TSP) LC                24 HOUR  ...
# 1 -86.844112  WGS84  Carbon monoxide                 1 HOUR  ...
# 2 -86.844112  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...
# 3 -86.844112  WGS84  Carbon monoxide                 1 HOUR  ...
# 4 -86.844112  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...
#
#   fiftieth_percentile tenth_percentile                   local_site_name  \
# 0               0.004            0.002  Pryor Field Lead Monitoring Site
# 1               0.370            0.240             Arkadelphia/Near Road
# 2               0.400            0.300             Arkadelphia/Near Road
# 3               0.380            0.260             Arkadelphia/Near Road
# 4               0.400            0.300             Arkadelphia/Near Road
#
#                                 site_address    state     county        city  \
# 0  US 31, Local On Calhoun Community College  Alabama  Limestone      Athens
# 1  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 2  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 3  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 4  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
#
#    cbsa_code                   cbsa  date_of_last_change
# 0      26620         Huntsville, AL           2013-06-28
# 1      13820  Birmingham-Hoover, AL           2017-04-18
# 2      13820  Birmingham-Hoover, AL           2017-04-18
# 3      13820  Birmingham-Hoover, AL           2017-04-18
# 4      13820  Birmingham-Hoover, AL           2017-04-18
#
# [5 rows x 55 columns]

# %%
all_state_aq_data.to_csv('data/all_states_raw_aq.csv')

# %%
# uncomment to read in the raw dataframe if we don't want to go through the process of fetching again
# all_state_aq_data = pd.read_csv('data/all_states_raw_aq.csv', index_col=0)

all_state_aq_data.shape
# Out:
# (90480, 55)

# %% [markdown]
# Let's also do some paring of this large number of columns. Many of these fields are superfluous for our analysis and so we can simply drop the columns (or in this case, keep the columns that we want).

# %%
all_state_aq_data.columns
# Out:
# Index(['state_code', 'county_code', 'site_number', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter', 'sample_duration',
#        'pollutant_standard', 'metric_used', 'method', 'year',
#        'units_of_measure', 'event_type', 'observation_count',
#        'observation_percent', 'validity_indicator', 'valid_day_count',
#        'required_day_count', 'exceptional_data_count',
#        'null_observation_count', 'primary_exceedance_count',
#        'secondary_exceedance_count', 'certification_indicator',
#        'arithmetic_mean', 'standard_deviation', 'first_max_value',
#        'first_max_datetime', 'second_max_value', 'second_max_datetime',
#        'third_max_value', 'third_max_datetime', 'fourth_max_value',
#        'fourth_max_datetime', 'first_max_nonoverlap_value',
#        'first_max_n_o_datetime', 'second_max_nonoverlap_value',
#        'second_max_n_o_datetime', 'ninety_ninth_percentile',
#        'ninety_eighth_percentile', 'ninety_fifth_percentile',
#        'ninetieth_percentile', 'seventy_fifth_percentile',
#        'fiftieth_percentile', 'tenth_percentile', 'local_site_name',
#        'site_address', 'state', 'county', 'city', 'cbsa_code', 'cbsa',
#        'date_of_last_change'],
#       dtype='object')

# %%
cols_to_drop = ['state_code', 'poc', 'latitude', 'longitude', 'datum', 'event_type', 'observation_percent', 'validity_indicator',
                'valid_day_count', 'required_day_count', 'primary_exceedance_count', 'secondary_exceedance_count', 
                'certification_indicator', 'first_max_value', 'first_max_datetime', 'second_max_value', 'second_max_datetime',
                'third_max_value', 'third_max_datetime', 'fourth_max_value', 'fourth_max_datetime', 'first_max_nonoverlap_value',
                'first_max_n_o_datetime', 'second_max_nonoverlap_value', 'second_max_n_o_datetime', 'ninety_ninth_percentile',
                'ninety_eighth_percentile', 'ninety_fifth_percentile', 'ninetieth_percentile', 'seventy_fifth_percentile',
                'fiftieth_percentile', 'tenth_percentile', 'cbsa_code', 'cbsa', 'pollutant_standard', 'method', 'metric_used']
all_state_aq_data.drop(columns=cols_to_drop, inplace=True)

# %%
all_state_aq_data.head()
# Out:
#    county_code  site_number  parameter_code        parameter  \
# 0           83            5           14129    Lead (TSP) LC
# 1           73         2059           42101  Carbon monoxide
# 2           73         2059           42101  Carbon monoxide
# 3           73         2059           42101  Carbon monoxide
# 4           73         2059           42101  Carbon monoxide
#
#          sample_duration  year             units_of_measure  \
# 0                24 HOUR  2012  Micrograms/cubic meter (LC)
# 1                 1 HOUR  2014            Parts per million
# 2  8-HR RUN AVG END HOUR  2014            Parts per million
# 3                 1 HOUR  2015            Parts per million
# 4  8-HR RUN AVG END HOUR  2015            Parts per million
#
#    observation_count  exceptional_data_count  null_observation_count  \
# 0                 58                       0                       4
# 1               8106                       0                     654
# 2               8415                       0                       0
# 3               7188                       0                    1572
# 4               7460                       0                       0
#
#    arithmetic_mean  standard_deviation                   local_site_name  \
# 0         0.006362            0.006212  Pryor Field Lead Monitoring Site
# 1         0.432750            0.216344             Arkadelphia/Near Road
# 2         0.436399            0.176097             Arkadelphia/Near Road
# 3         0.440380            0.215847             Arkadelphia/Near Road
# 4         0.443968            0.178687             Arkadelphia/Near Road
#
#                                 site_address    state     county        city  \
# 0  US 31, Local On Calhoun Community College  Alabama  Limestone      Athens
# 1  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 2  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 3  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
# 4  1110 5th Street West Birmingham, AL 35204  Alabama  Jefferson  Birmingham
#
#   date_of_last_change
# 0          2013-06-28
# 1          2017-04-18
# 2          2017-04-18
# 3          2017-04-18
# 4          2017-04-18

# %% [markdown]
# Let's also do a bit of investigation into the consistency of the data. In particular, there are various possible values represented in the `units_of_measure` field, leading us to suspect that perhaps we will need to do a bit of unit conversion before we are ready to begin analysis. To check if this is the case, we can group by the parameter name toogether with the units of measure. If we see that each name is associated to only a single unit, then we will know that we won't have to perform any unit conversions in order to compare within each compound present in the air.

# %%
all_state_aq_data.groupby(['parameter', 'units_of_measure']).count()
# Out:
#                                                         county_code  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                     3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)           1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)            181
# Nitrogen dioxide (NO2)   Parts per billion                     4499
# Ozone                    Parts per million                    29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)         8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)          32456
# Sulfur dioxide           Parts per billion                    10867
#
#                                                         site_number  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                     3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)           1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)            181
# Nitrogen dioxide (NO2)   Parts per billion                     4499
# Ozone                    Parts per million                    29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)         8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)          32456
# Sulfur dioxide           Parts per billion                    10867
#
#                                                         parameter_code  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                        3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)              1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)               181
# Nitrogen dioxide (NO2)   Parts per billion                        4499
# Ozone                    Parts per million                       29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)            8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)             32456
# Sulfur dioxide           Parts per billion                       10867
#
#                                                         sample_duration  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                         3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)               1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                181
# Nitrogen dioxide (NO2)   Parts per billion                         4499
# Ozone                    Parts per million                        29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)             8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)              32456
# Sulfur dioxide           Parts per billion                        10867
#
#                                                          year  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million               3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)     1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)      181
# Nitrogen dioxide (NO2)   Parts per billion               4499
# Ozone                    Parts per million              29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)   8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)    32456
# Sulfur dioxide           Parts per billion              10867
#
#                                                         observation_count  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                           3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)                 1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                  181
# Nitrogen dioxide (NO2)   Parts per billion                           4499
# Ozone                    Parts per million                          29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)               8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)                32456
# Sulfur dioxide           Parts per billion                          10867
#
#                                                         exceptional_data_count  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                                3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)                      1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                       181
# Nitrogen dioxide (NO2)   Parts per billion                                4499
# Ozone                    Parts per million                               29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)                    8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)                     32456
# Sulfur dioxide           Parts per billion                               10867
#
#                                                         null_observation_count  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                                3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)                      1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                       181
# Nitrogen dioxide (NO2)   Parts per billion                                4499
# Ozone                    Parts per million                               29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)                    8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)                     32456
# Sulfur dioxide           Parts per billion                               10867
#
#                                                         arithmetic_mean  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                         3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)               1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                181
# Nitrogen dioxide (NO2)   Parts per billion                         4499
# Ozone                    Parts per million                        29523
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)             8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)              32456
# Sulfur dioxide           Parts per billion                        10867
#
#                                                         standard_deviation  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                            3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)                  1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                   181
# Nitrogen dioxide (NO2)   Parts per billion                            4499
# Ozone                    Parts per million                           29523
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)                8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)                 32456
# Sulfur dioxide           Parts per billion                           10867
#
#                                                         local_site_name  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                         3098
# Lead (TSP) LC            Micrograms/cubic meter (LC)               1155
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                181
# Nitrogen dioxide (NO2)   Parts per billion                         4181
# Ozone                    Parts per million                        28093
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)             7802
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)              31523
# Sulfur dioxide           Parts per billion                         9785
#
#                                                         site_address  state  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                      3314   3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)            1335   1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)             181    181
# Nitrogen dioxide (NO2)   Parts per billion                      4499   4499
# Ozone                    Parts per million                     29525  29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)          8303   8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)           32448  32456
# Sulfur dioxide           Parts per billion                     10867  10867
#
#                                                         county   city  \
# parameter                units_of_measure
# Carbon monoxide          Parts per million                3314   2996
# Lead (TSP) LC            Micrograms/cubic meter (LC)      1335   1071
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)       181    164
# Nitrogen dioxide (NO2)   Parts per billion                4499   3497
# Ozone                    Parts per million               29525  20049
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)    8303   6701
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)     32456  27811
# Sulfur dioxide           Parts per billion               10867   8542
#
#                                                         date_of_last_change
# parameter                units_of_measure
# Carbon monoxide          Parts per million                             3314
# Lead (TSP) LC            Micrograms/cubic meter (LC)                   1335
# Lead PM10 LC FRM/FEM     Micrograms/cubic meter (LC)                    181
# Nitrogen dioxide (NO2)   Parts per billion                             4499
# Ozone                    Parts per million                            29525
# PM10 Total 0-10um STP    Micrograms/cubic meter (25 C)                 8303
# PM2.5 - Local Conditions Micrograms/cubic meter (LC)                  32456
# Sulfur dioxide           Parts per billion                            10867

# %% [markdown]
# We see that in fact, it is the case that the units have already been standardized. Therefore, we don't need to do any unit conversion if we want to gain some actionable insights when making comparisons within a particular parameter. We also see that we have a lot more readings for the Ozone and PM 2.5 parameters.
#
# Let's further clean up the data by aggregating over the full period of time that is available, grouping by county, state, and parameter. This will allow us to gain consistency with the format of the CDC cancer data set that we have chosen to use.

# %%
all_state_aggregate_aq = all_state_aq_data.groupby(by=['state', 'county', 'parameter']).mean().reset_index()

# %%
all_state_aggregate_aq.head(20)
# Out:
#       state     county                 parameter  county_code  site_number  \
# 0   Alabama    Baldwin                     Ozone          3.0    10.000000
# 1   Alabama    Baldwin  PM2.5 - Local Conditions          3.0    10.000000
# 2   Alabama       Clay  PM2.5 - Local Conditions         27.0     1.000000
# 3   Alabama    Colbert                     Ozone         33.0  1002.000000
# 4   Alabama    Colbert  PM2.5 - Local Conditions         33.0  1002.000000
# 5   Alabama     DeKalb                     Ozone         49.0  9991.000000
# 6   Alabama     DeKalb  PM2.5 - Local Conditions         49.0  1003.000000
# 7   Alabama     Elmore                     Ozone         51.0     1.000000
# 8   Alabama     Etowah                     Ozone         55.0    11.000000
# 9   Alabama     Etowah  PM2.5 - Local Conditions         55.0    10.000000
# 10  Alabama    Houston                     Ozone         69.0     4.000000
# 11  Alabama    Houston  PM2.5 - Local Conditions         69.0     3.000000
# 12  Alabama  Jefferson           Carbon monoxide         73.0  1862.052632
# 13  Alabama  Jefferson      Lead PM10 LC FRM/FEM         73.0    23.000000
# 14  Alabama  Jefferson    Nitrogen dioxide (NO2)         73.0   895.571429
# 15  Alabama  Jefferson                     Ozone         73.0  2331.648649
# 16  Alabama  Jefferson     PM10 Total 0-10um STP         73.0  2866.059524
# 17  Alabama  Jefferson  PM2.5 - Local Conditions         73.0  1242.684211
# 18  Alabama  Jefferson            Sulfur dioxide         73.0   513.000000
# 19  Alabama  Limestone             Lead (TSP) LC         83.0     5.000000
#
#     parameter_code         year  observation_count  exceptional_data_count  \
# 0          44201.0  2014.000000        5176.850000                0.000000
# 1          88101.0  2014.000000         116.800000                0.000000
# 2          88101.0  2014.000000         116.200000                0.000000
# 3          44201.0  2014.000000        5335.700000                0.000000
# 4          88101.0  2014.000000         118.600000                0.000000
# 5          44201.0  2014.000000        7877.450000                0.000000
# 6          88101.0  2014.000000         114.000000                0.000000
# 7          44201.0  2014.000000        4766.950000                0.000000
# 8          44201.0  2014.000000        5257.500000                0.000000
# 9          88101.0  2014.000000         113.800000                0.000000
# 10         44201.0  2014.000000        5324.650000                0.000000
# 11         88101.0  2014.000000         117.800000                0.000000
# 12         42101.0  2013.894737        7948.000000                0.000000
# 13         85129.0  2014.000000          53.900000                0.000000
# 14         42602.0  2014.714286        6603.714286                0.000000
# 15         44201.0  2013.891892        5619.195946                0.000000
# 16         81102.0  2014.119048        2304.464286              712.833333
# 17         88101.0  2014.105263         333.385965              232.850877
# 18         42401.0  2014.000000        4518.675000                0.000000
# 19         14129.0  2012.000000          58.000000                0.000000
#
#     null_observation_count  arithmetic_mean  standard_deviation
# 0               120.200000         0.041641            0.012011
# 1                 5.200000         8.469895            3.431420
# 2                 6.200000         8.291026            3.646928
# 3                76.600000         0.041134            0.010685
# 4                 3.400000         8.589856            3.836046
# 5               116.850000         0.044970            0.009932
# 6                 7.800000         8.929633            3.813341
# 7                75.050000         0.041555            0.010264
# 8                97.350000         0.042401            0.010022
# 9                 8.000000         9.099492            3.546380
# 10               82.600000         0.039522            0.010810
# 11                4.000000         8.028497            3.231636
# 12              385.763158         0.357241            0.205106
# 13                1.200000         0.013881            0.026308
# 14             1018.000000        18.346102            9.777276
# 15              117.378378         0.043834            0.011632
# 16              186.714286        19.022404           10.789991
# 17               69.464912        10.615216            4.412238
# 18              563.450000         2.221072            2.789349
# 19                4.000000         0.006362            0.006212

# %%
all_state_aggregate_aq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2921 entries, 0 to 2920
# Data columns (total 12 columns):
# state                     2921 non-null object
# county                    2921 non-null object
# parameter                 2921 non-null object
# county_code               2921 non-null float64
# site_number               2921 non-null float64
# parameter_code            2921 non-null float64
# year                      2921 non-null float64
# observation_count         2921 non-null float64
# exceptional_data_count    2921 non-null float64
# null_observation_count    2921 non-null float64
# arithmetic_mean           2921 non-null float64
# standard_deviation        2921 non-null float64
# dtypes: float64(9), object(3)
# memory usage: 274.0+ KB

# %% [markdown]
# For ease of merging later on, let's also convert the state column into their standard abbreviations. We'll also remove data points from areas not included in the usual 50 states plus DC, such as readings from Puerto Rico. This is to facilitate ease of merging with the CDC data later on, as cancer rates are not included in that data for these areas. To do so, we'll need a dictionary containing the standard abbreviations associated to state names.

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District Of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %% [markdown]
# Now we can use this to convert the state column. First, let's remove the extra areas of Mexico, Puerto Rico, and the Virgin Islands.

# %%
all_state_aggregate_aq = all_state_aggregate_aq.loc[
    (all_state_aggregate_aq.state != 'Country Of Mexico')
    & (all_state_aggregate_aq.state != 'Virgin Islands')
    & (all_state_aggregate_aq.state != 'Puerto Rico')]

# %%
all_state_aggregate_aq.state = all_state_aggregate_aq.state.map(lambda s: us_state_abbrev[s])

# %%
all_state_aggregate_aq.head()
# Out:
#   state   county                 parameter  county_code  site_number  \
# 0    AL  Baldwin                     Ozone          3.0         10.0
# 1    AL  Baldwin  PM2.5 - Local Conditions          3.0         10.0
# 2    AL     Clay  PM2.5 - Local Conditions         27.0          1.0
# 3    AL  Colbert                     Ozone         33.0       1002.0
# 4    AL  Colbert  PM2.5 - Local Conditions         33.0       1002.0
#
#    parameter_code    year  observation_count  exceptional_data_count  \
# 0         44201.0  2014.0            5176.85                     0.0
# 1         88101.0  2014.0             116.80                     0.0
# 2         88101.0  2014.0             116.20                     0.0
# 3         44201.0  2014.0            5335.70                     0.0
# 4         88101.0  2014.0             118.60                     0.0
#
#    null_observation_count  arithmetic_mean  standard_deviation
# 0                   120.2         0.041641            0.012011
# 1                     5.2         8.469895            3.431420
# 2                     6.2         8.291026            3.646928
# 3                    76.6         0.041134            0.010685
# 4                     3.4         8.589856            3.836046

# %% [markdown]
# Finally, let's save our cleaned and aggregated dataframe as a csv file in the [`cleaned_data`](./cleaned_data/) folder, for ease of access later on.

# %%
all_state_aggregate_aq.to_csv('cleaned_data/all_states_aq.csv')

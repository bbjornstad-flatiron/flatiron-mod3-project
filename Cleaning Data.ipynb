# %%
import pandas as pd

# %%
df = pd.read_excel('Lung_Cancer_Incidence.xlsx')
df.head()
# Out:
#     Category      Subcategory              Indicator       Year Geography  \
# 0  Morbidity  Chronic Disease  Lung cancer incidence  2011-2015      City
# 1  Morbidity  Chronic Disease  Lung cancer incidence  2011-2015      City
# 2  Morbidity  Chronic Disease  Lung cancer incidence  2011-2015      City
# 3  Morbidity  Chronic Disease  Lung cancer incidence  2011-2015      City
# 4  Morbidity  Chronic Disease  Lung cancer incidence  2011-2015      City
#
#   Geo_Group  Geo_ID Demography Demo_Group Number ...   \
# 0   Chicago     606        Age      00-14    NaN ...
# 1   Chicago     606        Age      15-34    NaN ...
# 2   Chicago     606        Age      35-44    NaN ...
# 3   Chicago     606        Age      45-54    NaN ...
# 4   Chicago     606        Age      55-64    NaN ...
#
#    Upper_95CI_Age_Adj_Rate  Percent  Lower_95CI_Percent  Upper_95CI_Percent  \
# 0                      0.0
# 1                      0.8
# 2                      5.0
# 3                     41.1
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Subcategory', 'Indicator', 'Year', 'Geography',
#        'Geo_Group', 'Geo_ID', 'Demography', 'Demo_Group', 'Number',
#        'Cum_Number', 'Ave_Annual_Number', 'CRUDE_RATE',
#        'Lower_95CI_Crude_Rate', 'Upper_95CI_Crude_Rate', 'Age_Adj_Rate',
#        'Lower_95CI_Age_Adj_Rate', 'Upper_95CI_Age_Adj_Rate', 'Percent',
#        'Lower_95CI_Percent', 'Upper_95CI_Percent', 'Weight_Number',
#        'Weight_Percent', 'Lower_95CI_Weight_Percent',
#        'Upper_95CI_Weight_Percent', 'Map_Key', 'Flag'],
#       dtype='object')

# %%
df.drop(columns=['Category', 'Subcategory', 'Indicator', 'CRUDE_RATE',
       'Lower_95CI_Crude_Rate', 'Upper_95CI_Crude_Rate', 'Age_Adj_Rate',
       'Lower_95CI_Age_Adj_Rate', 'Upper_95CI_Age_Adj_Rate', 'Percent',
       'Lower_95CI_Percent', 'Upper_95CI_Percent', 'Weight_Number',
       'Weight_Percent', 'Lower_95CI_Weight_Percent',
       'Upper_95CI_Weight_Percent', 'Map_Key', 'Flag'], inplace=True)
df.head()
# Out:
#         Year Geography Geo_Group  Geo_ID Demography Demo_Group Number  \
# 0  2011-2015      City   Chicago     606        Age      00-14    NaN
# 1  2011-2015      City   Chicago     606        Age      15-34    NaN
# 2  2011-2015      City   Chicago     606        Age      35-44    NaN
# 3  2011-2015      City   Chicago     606        Age      45-54    NaN
# 4  2011-2015      City   Chicago     606        Age      55-64    NaN
#
#    Cum_Number  Ave_Annual_Number
# 0           1                  0
# 1          24                  5
# 2          76                 15
# 3         647                129
# 4        1958                392

# %%
df = df[df.Geo_Group != 'Chicago']
df.head()
# Out:
#          Year       Geography         Geo_Group  Geo_ID Demography Demo_Group  \
# 15  2011-2015  Community Area     1-Rogers Park       1        NaN        NaN
# 16  2011-2015  Community Area      2-West Ridge       2        NaN        NaN
# 17  2011-2015  Community Area          3-Uptown       3        NaN        NaN
# 18  2011-2015  Community Area  4-Lincoln Square       4        NaN        NaN
# 19  2011-2015  Community Area    5-North Center       5        NaN        NaN
#
#    Number  Cum_Number  Ave_Annual_Number
# 15    NaN         132                 26
# 16    NaN         193                 39
# 17    NaN         149                 30
# 18    NaN          71                 14
# 19    NaN          69                 14

# %%
df
# Out:
#           Year       Geography                  Geo_Group  Geo_ID Demography  \
# 15   2011-2015  Community Area              1-Rogers Park       1        NaN
# 16   2011-2015  Community Area               2-West Ridge       2        NaN
# 17   2011-2015  Community Area                   3-Uptown       3        NaN
# 18   2011-2015  Community Area           4-Lincoln Square       4        NaN
# 19   2011-2015  Community Area             5-North Center       5        NaN
# 20   2011-2015  Community Area                 6-Lakeview       6        NaN
# 21   2011-2015  Community Area             7-Lincoln Park       7        NaN
# 22   2011-2015  Community Area          8-Near North Side       8        NaN
# 23   2011-2015  Community Area              9-Edison Park       9        NaN
# 24   2011-2015  Community Area            10-Norwood Park      10        NaN
# 25   2011-2015  Community Area          11-Jefferson Park      11        NaN
# ...

# %%
df.drop(columns=['Demography', 'Demo_Group', 'Number'], inplace=True)
df = df[df.Year != '2004-2008']
df
# Out:
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#           Year       Geography                  Geo_Group  Geo_ID  Cum_Number  \
# 15   2011-2015  Community Area              1-Rogers Park       1         132
# 16   2011-2015  Community Area               2-West Ridge       2         193
# 17   2011-2015  Community Area                   3-Uptown       3         149
# 18   2011-2015  Community Area           4-Lincoln Square       4          71
# 19   2011-2015  Community Area             5-North Center       5          69
# 20   2011-2015  Community Area                 6-Lakeview       6         145
# 21   2011-2015  Community Area             7-Lincoln Park       7         134
# ...

# %%
df = df[df.Year != '2009-2013']
df
# Out:
#           Year       Geography                  Geo_Group  Geo_ID  Cum_Number  \
# 15   2011-2015  Community Area              1-Rogers Park       1         132
# 16   2011-2015  Community Area               2-West Ridge       2         193
# 17   2011-2015  Community Area                   3-Uptown       3         149
# 18   2011-2015  Community Area           4-Lincoln Square       4          71
# 19   2011-2015  Community Area             5-North Center       5          69
# 20   2011-2015  Community Area                 6-Lakeview       6         145
# 21   2011-2015  Community Area             7-Lincoln Park       7         134
# 22   2011-2015  Community Area          8-Near North Side       8         255
# 23   2011-2015  Community Area              9-Edison Park       9          39
# 24   2011-2015  Community Area            10-Norwood Park      10         182
# 25   2011-2015  Community Area          11-Jefferson Park      11         101
# ...

# %%
df = df[df.Year != '2005-2009']
df
# Out:
#           Year       Geography                  Geo_Group  Geo_ID  Cum_Number  \
# 15   2011-2015  Community Area              1-Rogers Park       1         132
# 16   2011-2015  Community Area               2-West Ridge       2         193

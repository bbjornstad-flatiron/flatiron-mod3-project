# %%
from pyaqs import AQSFetcher
import pandas as pd

# %%
test_fetcher = AQSFetcher('bbjornstad.flatiron@gmail.com', 'ochrefox21')

# %%
state_codes = test_fetcher.get_state_codes()
il_code = state_codes.loc[state_codes['state_name'] == 'Illinois', 'code']
il_code = il_code.values[0]

# %%
il_code
# Out:
# '17'

# %%
county_codes = test_fetcher.get_counties_by_state(il_code)

# %%
cook_code = county_codes.loc[county_codes['county_name'] == 'Cook', 'code'].values[0]
cook_code
# Out:
# '031'

# %%
site_codes = test_fetcher.get_sites_by_county(il_code, cook_code)

# %%
site_codes.dropna(inplace=True)
site_codes
# Out:
#      code                                          site_name
# 0    0001                                     VILLAGE GARAGE
# 13   0014                                          FARR HALL
# 21   0022                                      WASHINGTON HS
# 24   0026                                CERMAK PUMP STATION
# 30   0032                       SOUTH WATER FILTRATION PLANT
# 40   0042                                        SEARS TOWER
# 46   0050                                  SE POLICE STATION
# 48   0052                               MAYFAIR PUMP STATION
# 53   0057                           SPRINGFIELD PUMP STATION
# 56   0060                                          CARVER HS
# 58   0063                                       CTA BUILDING
# 59   0064                              UNIVERSITY OF CHICAGO
# 65   0072                                JARDINE WATER PLANT
# 66   0073  MONITOR LOCATED 9 M FROM NORTH EDGE AND 8 M FR...
# ...

# %%
test_fetcher.get_parameter_classes()
# Out:
#                  class_name                                  class_description
# 0               AIRNOW MAPS  The parameters represented on AirNow maps (881...
# 1                       ALL                    Select all Parameters Available
# 2            AQI POLLUTANTS                Pollutants that have an AQI Defined
# 3                 CORE_HAPS                         Urban Air Toxic Pollutants
# 4                  CRITERIA                                Criteria Pollutants
# 5                  CSN DART  List of CSN speciation parameters to populate ...
# 6                  FORECAST     Parameters routinely extracted by AirNow (STI)
# 7                      HAPS                           Hazardous Air Pollutants
# 8            IMPROVE CARBON                          IMPROVE Carbon Parameters
# 9        IMPROVE_SPECIATION  PM2.5 Speciated Parameters Measured at IMPROVE...
# 10                      MET                            Meteorologic Parameters
# ...

# %%
criteria_params = test_fetcher.get_parameter_list_by_class('CRITERIA')
criteria_params
# Out:
#     code     parameter_description
# 0  14129             Lead (TSP) LC
# 1  42101           Carbon monoxide
# 2  42401            Sulfur dioxide
# 3  42602    Nitrogen dioxide (NO2)
# 4  44201                     Ozone
# 5  81102     PM10 Total 0-10um STP
# 6  85129      Lead PM10 LC FRM/FEM
# 7  88101  PM2.5 - Local Conditions

# %%
test_fetcher.annual_data_by_site(il_code, cook_code, '0042', criteria_params.code, 19500101, 20151231)
# Out:
#    state_code county_code site_number parameter_code  poc  latitude  \
# 0          17         031        0042          44201    2  41.87898
# 1          17         031        0042          44201    2  41.87898
# 2          17         031        0042          44201    2  41.87898
# 3          17         031        0042          44201    2  41.87898
# 4          17         031        0042          44201    2  41.87898
# ..        ...         ...         ...            ...  ...       ...
# 91         17         031        0042          44201    2  41.87898
# 92         17         031        0042          44201    2  41.87898
# 93         17         031        0042          44201    2  41.87898
# 94         17         031        0042          44201    1  41.87898
# 95         17         031        0042          44201    1  41.87898
#
#     longitude  datum parameter          sample_duration  ...  \
# 0  -87.635556  WGS84     Ozone                   1 HOUR  ...
# ...

# %%
test_fetcher.annual_data_by_county(il_code, cook_code, criteria_params.code, 20120101, 20161231)
# Out:
#     state_code county_code site_number parameter_code  poc   latitude  \
# 0           17         031        4007          44201    1  42.060285
# 1           17         031        4007          44201    1  42.060285
# 2           17         031        4007          44201    1  42.060285
# 3           17         031        4007          44201    1  42.060285
# 4           17         031        4007          44201    1  42.060285
# ..         ...         ...         ...            ...  ...        ...
# 691         17         031        7002          44201    1  42.062053
# 692         17         031        0113          14129    1  41.663611
# 693         17         031        0113          14129    1  41.663611
# 694         17         031        0113          14129    1  41.663611
# 695         17         031        0113          14129    1  41.663611
#
#      longitude  datum      parameter          sample_duration  ...  \
# ...

# %%
test_fetcher.annual_data_by_state(il_code, [42101], 20120101, 20161231)
# Out:
#    state_code county_code site_number parameter_code  poc   latitude  \
# 0          17         031        0063          42101    1  41.877682
# 1          17         031        0063          42101    1  41.877682
# 2          17         031        4002          42101    1  41.855243
# 3          17         031        4002          42101    1  41.855243
# 4          17         163        0010          42101    1  38.612034
# 5          17         163        0010          42101    1  38.612034
# 6          17         163        0010          42101    1  38.612034
# 7          17         163        0010          42101    1  38.612034
# 8          17         163        0010          42101    1  38.612034
# 9          17         163        0010          42101    1  38.612034
# 10         17         163        0010          42101    1  38.612034
# 11         17         163        0010          42101    1  38.612034
# 12         17         163        0010          42101    1  38.612034
# ...
